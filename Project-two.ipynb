# %% [markdown]
# ## PROJECT TWO: Forbes Billionaires

# %%
# Import relevant dependencies

import pandas as pd
import numpy as np
from sqlalchemy import create_engine

# %%
# Import the csv file
forbes_data = pd.read_csv('Resources/forbes_billionaires_geo.csv')

# Preview the data
forbes_data.head()
# Out:
#                        Name  NetWorth        Country         Source  Rank  \
# 0                Jeff Bezos     177.0  United States         Amazon     1
# 1                 Elon Musk     151.0  United States  Tesla, SpaceX     2
# 2  Bernard Arnault & family     150.0         France           LVMH     3
# 3                Bill Gates     124.0  United States      Microsoft     4
# 4           Mark Zuckerberg      97.0  United States       Facebook     5
#
#     Age              Residence    Citizenship           Status  Children  \
# 0  57.0    Seattle, Washington  United States  In Relationship       4.0
# 1  49.0          Austin, Texas  United States  In Relationship       7.0
# 2  72.0          Paris, France         France          Married       5.0
# 3  65.0     Medina, Washington  United States         Divorced       3.0
# 4  36.0  Palo Alto, California  United States          Married       2.0
#
#                                            Education Self_made  \
# 0     Bachelor of Arts/Science, Princeton University      True
# 1  Bachelor of Arts/Science, University of Pennsy...      True
# 2  Bachelor of Arts/Science, Ecole Polytechnique ...     False
# 3                       Drop Out, Harvard University      True
# 4                       Drop Out, Harvard University      True
#
#                                 geometry
# 0        POINT (-122.3300624 47.6038321)
# 1  POINT (-97.74369950000001 30.2711286)
# 2           POINT (2.3514616 48.8566969)
# 3         POINT (-122.2264453 47.620548)
# 4        POINT (-122.1598465 37.4443293)

# %%
# Split the Residence & Education columns

forbes_data[["Education - Degree", "Education - University"]] = forbes_data["Education"].str.split(',', 1, expand=True)

# %%
# Check n/a values
check_na = forbes_data.isnull().sum()
print (check_na)

# Checking if the name column has any null data
# We won't drop any n/a in columns except Name
# Because we want to display all their demographic information
# Out:
# Name                         0
# NetWorth                     0
# Country                      0
# Source                       0
# Rank                         0
# Age                        125
# Residence                   40
# Citizenship                 16
# Status                     665
# Children                  1203
# Education                 1346
# Self_made                   18
# geometry                     0
# Education - Degree        1346
# Education - University    1365
# dtype: int64

# %%
# Split geometry & drop the geometry columns 

forbes_data[["geometry1", "Longitude_Latitude"]] = forbes_data["geometry"].str.split(' ', 1, expand=True)
forbes_data = forbes_data.drop(columns=["geometry", "geometry1"])

# Split longitude & latitude again into separate columns & drop the original column

forbes_data[["Longitude", "Latitude"]] = forbes_data["Longitude_Latitude"].str.split(' ', 1, expand=True)
forbes_data = forbes_data.drop(columns=["Longitude_Latitude"])

# Remove the brackets on both columns

forbes_data["Longitude"] = forbes_data["Longitude"].str[1:]
forbes_data["Latitude"] = forbes_data["Latitude"].str[:-1]

# %%
# Create a new column to base on different range of Net Worth, for plotting purposes

forbes_data["Grouped_NetWorth"] = ["Over $70 b" if x >= 70 
                        else "Over $20 b" if 20<=x<70 
                        else "the rest" for x in forbes_data["NetWorth"]]

# %%
# Preview the data

#forbes_data.head()

# %%
# Creating a new column with combined first & last name & change all cases to lower case
forbes_data["Full_name"] = forbes_data["Name"].str.lower()

# %%
# Remove extra characters in the names
forbes_data["Full_name"]=forbes_data["Full_name"].str.rstrip('& familyNone')

# %%
# Replace all space to a '-'
spaces = [" "]
for space in spaces:
    forbes_data["Full_name"]=forbes_data["Full_name"].str.replace(space, "-")

# %%
# Preview the data

# forbes_data.head()

# %%
# Rename all columns to lower cases - to import into postgreSQL

forbes_data = forbes_data.rename(columns={
    "Name": "name", 
    "NetWorth": "networth", 
    "Country": "country", 
    "Source": "source",
    "Rank": "rank", 
    "Age": "age", 
    "Residence": "residence", 
    "Citizenship": "citizenship", 
    "Status": "status",
    "Children": "children", 
    "Education": "education",
    "Self_made": "self_made", 
    "Education - Degree": "degree", 
    "Education - University": "university",
    "Longitude": "longitude", 
    "Latitude": "latitude",
    "Grouped_NetWorth": "groupednetworth",
    "Full_name": "fullname"})

# %%
# Rename the index to align with the name in the table created in postgreSQL

forbes_data.index.names = ['id']

# %%
# Preview the data

forbes_data.head()
# Out:
#                         name  networth        country         source  rank  \
# id
# 0                 Jeff Bezos     177.0  United States         Amazon     1
# 1                  Elon Musk     151.0  United States  Tesla, SpaceX     2
# 2   Bernard Arnault & family     150.0         France           LVMH     3
# 3                 Bill Gates     124.0  United States      Microsoft     4
# 4            Mark Zuckerberg      97.0  United States       Facebook     5
#
#      age              residence    citizenship           status  children  \
# id
# 0   57.0    Seattle, Washington  United States  In Relationship       4.0
# 1   49.0          Austin, Texas  United States  In Relationship       7.0
# 2   72.0          Paris, France         France          Married       5.0
# 3   65.0     Medina, Washington  United States         Divorced       3.0
# 4   36.0  Palo Alto, California  United States          Married       2.0
#
#                                             education self_made  \
# id
# 0      Bachelor of Arts/Science, Princeton University      True
# 1   Bachelor of Arts/Science, University of Pennsy...      True
# 2   Bachelor of Arts/Science, Ecole Polytechnique ...     False
# 3                        Drop Out, Harvard University      True
# 4                        Drop Out, Harvard University      True
#
#                       degree                     university  \
# id
# 0   Bachelor of Arts/Science           Princeton University
# 1   Bachelor of Arts/Science     University of Pennsylvania
# 2   Bachelor of Arts/Science   Ecole Polytechnique de Paris
# 3                   Drop Out             Harvard University
# 4                   Drop Out             Harvard University
#
#              longitude    latitude groupednetworth         fullname
# id
# 0         -122.3300624  47.6038321      Over $70 b       jeff-bezos
# 1   -97.74369950000001  30.2711286      Over $70 b        elon-musk
# 2            2.3514616  48.8566969      Over $70 b  bernard-arnault
# 3         -122.2264453   47.620548      Over $70 b       bill-gates
# 4         -122.1598465  37.4443293      Over $70 b  mark-zuckerberg

# %%
# Export the data to csv

forbes_data.to_csv('forbes_cleandata.csv')

# %%
# Check all column types to assist creating table in postgreSQL
forbes_data.dtypes
# Out:
# name                object
# networth           float64
# country             object
# source              object
# rank                 int64
# age                float64
# residence           object
# citizenship         object
# status              object
# children           float64
# education           object
# self_made           object
# degree              object
# university          object
# longitude           object
# latitude            object
# groupednetworth     object
# fullname            object
# dtype: object

# %% [markdown]
# ### Create database connection

# %%
# Connect the engine with URI on heroku

engine = create_engine("postgres://hqbkvuzhrlymzx:c08cc2098824445764cd8413ee9d5f79d029847ac2c6cf949ce50d490de2df3d@ec2-3-214-136-47.compute-1.amazonaws.com:5432/d3itds64i4rb7k")

# %%
# Confirm tables

engine.table_names()
# Out:
# ['forbes_billionaires']

# %% [markdown]
# ### Loading into PostgreSQL

# %%
# Loading into Postgre

forbes_data.to_sql(name='forbes_billionaires', con=engine, if_exists='append', index=True)

# %%
# Preview the final table in SQL

pd.read_sql_query('select * from forbes_billionaires', con=engine).head()
# Out:
#      id                    name  networth        country             source  \
# 0  1548               Li Weiwei       2.1          China       online games
# 1  1549            Lin Chen-hai       2.1         Taiwan        real estate
# 2  1550              Lin Yinsun       2.1          China       agribusiness
# 3  1551  Liu Zhongtian & family       2.1          China  aluminum products
# 4  1552         Daniel Lubetzky       2.1  United States         snack bars
#
#    rank   age           residence    citizenship   status  children  \
# 0  1517  44.0     Shanghai, China          China     None       NaN
# 1  1517  74.0      Taipei, Taiwan         Taiwan  Married       2.0
# 2  1517  57.0     Shanghai, China          China     None       NaN
# 3  1517  57.0     Liaoyang, China          China  Married       NaN
# 4  1517  52.0  New York, New York  United States  Married       4.0
#
#                                            education self_made  \
# 0                                               None      true
# 1                                               None      true
# 2   EMBA, China Europe International Business School      true
# 3          Diploma, Liaoning Radio and TV University      true
# 4  Bachelor of Arts/Science, Trinity University o...      true
#
#                      degree                                   university  \
# 0                      None                                         None
# 1                      None                                         None
# 2                      EMBA   China Europe International Business School
# 3                   Diploma             Liaoning Radio and TV University
# 4  Bachelor of Arts/Science            Trinity University of San Antonio
#
#     longitude   latitude groupednetworth        fullname
# 0  121.469207  31.232276        the rest         li-weiw
# 1  121.563680  25.037520        the rest      lin-chen-h
# 2  121.469207  31.232276        the rest       lin-yinsu
# 3  123.169346  41.273887        the rest      liu-zhongt
# 4  -74.006015  40.712728        the rest  daniel-lubetzk
